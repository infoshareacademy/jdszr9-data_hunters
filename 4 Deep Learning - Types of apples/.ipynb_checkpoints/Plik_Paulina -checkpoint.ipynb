# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import cv2
import matplotlib.pyplot as plt
import os
import random
from lime import lime_image
from skimage.segmentation import mark_boundaries
from PIL import Image
from IPython.display import display

from Utilities.processing_files import split_to_train_test
from Utilities.generators import create_ultra_test_generator, create_generators
from Utilities.output import plot_history, print_confusion_matrix, get_y_pred
from Utilities.models import load_netv2_model, create_model, load_model

# %%
categories=("A", "B", "C", "D", "E", "F")
NUM_OUTPUTS= len(categories)
IMG_SIZE=(322, 322)
input_shape = IMG_SIZE + (3,)
BATCH_SIZE = 56
N_VALIDATION = 0.1

# %%
def load_random_photo(folder):
    files = os.listdir(folder)
    random_file = random.choice(files)
    
    img = cv2.imread(folder+"/"+random_file)
    img = transform_photo(img)
    class_img=random_file[0]
    return img, class_img

def show_random_photo_from_category(folder, category):
    folder =os.path.join(folder, category)
    files = os.listdir(folder)
    random_file = random.choice(files)
    
    img = cv2.imread(folder+"/"+random_file)
    img = transform_photo(img)
    
    #fig = plt.figure(figsize=(20,10))
    #plt.imshow(img)
    #plt.title("Category: "+category)
    #plt.show()
    return img


def transform_photo(img):
    new_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return new_img

def show_photo(img, category):
    print("Kategoria zdjęcia: " +category)
    fig = plt.figure(figsize=(20,10))
    plt.imshow(img)
    plt.show()

# %% [markdown]
# # DATA_HUNTERS - DL PROJECT

# %% [markdown]
# ## Arek
# ## Marta
# ## Paulina
# ## Asia

# %% [markdown]
# # CEL PROJEKTU

# %% [markdown]
# ### Rozpoznawanie klas jabłek w fabryce dżemów

# %% [markdown]
# # DANE

# %%
paths = ["Apple_A.png", "Apple_B.png", "Apple_C.png", "Apple_D.png", "Apple_E.png", "Apple_F.png"]

fig, axes = plt.subplots(2, 3, figsize=(10, 6))

for i, ax in enumerate(axes.flat):
    image = Image.open(paths[i])
    ax.imshow(image)
    ax.set_title("Image {}".format(paths[i][6]))  # Dodaj tytuł zdjęcia
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Zdjęcia jabłek pogrupowane w 6 klas pod względem ich rodzaju

# %% [markdown]
# # MODEL

# %%
#     split_to_train_test("data/")
#from google.colab import drive
#drive.mount('/content/drive')

# %%
train_generator, val_generator, test_generator = create_generators("data", batch_size= BATCH_SIZE, n_val = N_VALIDATION)
# Out:
# Found 5033 images belonging to 6 classes.
# Found 556 images belonging to 6 classes.
# Found 546 images belonging to 6 classes.

# %%
ultra_test_generator = create_ultra_test_generator("data", batch_size= BATCH_SIZE)
# Out:
# Found 26 images belonging to 6 classes.

# %% [markdown]
# # Architektura własnego modelu, oraz modelu NetV2

# %% [markdown]
# Function to split data to usefull folders

# %%
model_my=tf.keras.models.load_model('models/my_model.keras')
model_my.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 322, 322, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 161, 161, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 161, 161, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 80, 80, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 80, 80, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 40, 40, 64)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d_3 (MaxPoolin  (None, 20, 20, 64)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 20, 20, 64)        36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 10, 10, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dense_1 (Dense)             (None, 322)               2061122
#
#  activation (Activation)     (None, 322)               0
#
#  dropout_1 (Dropout)         (None, 322)               0
#
#  dense_2 (Dense)             (None, 6)                 1938
#
#  activation_1 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 2193236 (8.37 MB)
# Trainable params: 2193236 (8.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model_my.fit_generator(generator=train_generator,
    steps_per_epoch=len(train_generator),
    epochs=10,
    validation_data=val_generator,
    validation_steps= len(val_generator)
                             )
# Out:
# C:\Users\arkad\AppData\Local\Temp\ipykernel_31500\753656592.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model_my.fit_generator(generator=train_generator,
# Epoch 1/10
# 90/90 [==============================] - 632s 7s/step - loss: 0.8880 - accuracy: 0.6624 - val_loss: 0.4559 - val_accuracy: 0.8381
# Epoch 2/10
# 90/90 [==============================] - 580s 6s/step - loss: 0.0768 - accuracy: 0.9754 - val_loss: 0.0450 - val_accuracy: 0.9928
# Epoch 3/10
# 90/90 [==============================] - 582s 6s/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.1269 - val_accuracy: 0.9424
# Epoch 4/10
# 90/90 [==============================] - 573s 6s/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.0299 - val_accuracy: 0.9874
# Epoch 5/10
# 90/90 [==============================] - 544s 6s/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.2282 - val_accuracy: 0.9155
# Epoch 6/10
# 90/90 [==============================] - 547s 6s/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0180 - val_accuracy: 0.9910
# Epoch 7/10
# 90/90 [==============================] - 566s 6s/step - loss: 0.0082 - accuracy: 0.9966 - val_loss: 0.1282 - val_accuracy: 0.9424
# Epoch 8/10
# 90/90 [==============================] - 576s 6s/step - loss: 0.0307 - accuracy: 0.9899 - val_loss: 0.0854 - val_accuracy: 0.9640
# Epoch 9/10
# 90/90 [==============================] - 570s 6s/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0402 - val_accuracy: 0.9910
# Epoch 10/10
# 90/90 [==============================] - 507s 6s/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 0.0421 - val_accuracy: 0.9874

# %% [markdown]
# # Wykres uczenia się naszego modelu

# %%
acc = []
val_acc = []
for i in range(len(history.history["accuracy"])):
    acc.append( history.history["accuracy"][i])
    val_acc.append( history.history["val_accuracy"][i])
hist_df = pd.DataFrame({"# Epoch": [e for e in range(1,len(acc)+1)],"Accuracy": acc, "Val_accuracy": val_acc})
hist_df.plot(x = "# Epoch", y = ["Accuracy","Val_accuracy"])
plt.title("Accuracy vs Validation Accuracy")
plt.show()

# %%
history = model_net.fit_generator(generator=train_generator,
    steps_per_epoch=len(train_generator),
    epochs=10,
    validation_data=val_generator,
    validation_steps= len(val_generator)
                             )
# Out:
# C:\Users\Paulina\AppData\Local\Temp\ipykernel_14876\2265195917.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model_net.fit_generator(generator=train_generator,
# Epoch 1/10
# 85/85 [==============================] - 153s 2s/step - loss: 0.0238 - accuracy: 0.9977 - val_loss: 0.0264 - val_accuracy: 0.9942
# Epoch 2/10
# 85/85 [==============================] - 169s 2s/step - loss: 0.0211 - accuracy: 0.9994 - val_loss: 0.0349 - val_accuracy: 0.9866
# Epoch 3/10
# 85/85 [==============================] - 247s 3s/step - loss: 0.0182 - accuracy: 0.9985 - val_loss: 0.0337 - val_accuracy: 0.9904
# Epoch 4/10
# 85/85 [==============================] - 249s 3s/step - loss: 0.0156 - accuracy: 0.9996 - val_loss: 0.0392 - val_accuracy: 0.9866
# Epoch 5/10
# 85/85 [==============================] - 246s 3s/step - loss: 0.0151 - accuracy: 0.9992 - val_loss: 0.0331 - val_accuracy: 0.9904
# Epoch 6/10
# 85/85 [==============================] - 245s 3s/step - loss: 0.0138 - accuracy: 0.9987 - val_loss: 0.0438 - val_accuracy: 0.9846
# Epoch 7/10
# 85/85 [==============================] - 242s 3s/step - loss: 0.0134 - accuracy: 0.9989 - val_loss: 0.0479 - val_accuracy: 0.9827
# Epoch 8/10
# 85/85 [==============================] - 239s 3s/step - loss: 0.0122 - accuracy: 0.9994 - val_loss: 0.0435 - val_accuracy: 0.9846
# Epoch 9/10
# 85/85 [==============================] - 242s 3s/step - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.0406 - val_accuracy: 0.9846
# Epoch 10/10
# 85/85 [==============================] - 239s 3s/step - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.0395 - val_accuracy: 0.9866

# %% [markdown]
# # Wykres uczenia się modelu NETV2

# %%
acc = []
val_acc = []
for i in range(len(history.history["accuracy"])):
    acc.append( history.history["accuracy"][i])
    val_acc.append( history.history["val_accuracy"][i])
hist_df = pd.DataFrame({"# Epoch": [e for e in range(1,len(acc)+1)],"Accuracy": acc, "Val_accuracy": val_acc})
hist_df.plot(x = "# Epoch", y = ["Accuracy","Val_accuracy"])
plt.title("Accuracy vs Validation Accuracy")
plt.show()

# %% [markdown]
# # Predykcje dla naszego modelu, confusion matrix

# %%
y_pred_my= get_y_pred(model_my, test_generator)
y_true = test_generator.classes

print(classification_report(y_true, y_pred_my, target_names=categories))
# Out:
# C:\Users\arkad\Projekty DataHunters\jdszr9-data_hunters\4 Deep Learning - Types of apples\Utilities\output.py:30: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_generator, steps=len(test_generator), verbose=1)
# 10/10 [==============================] - 14s 1s/step
#               precision    recall  f1-score   support
#
#            A       0.98      1.00      0.99        61
#            B       1.00      0.99      0.99        79
#            C       1.00      1.00      1.00        68
#            D       0.99      1.00      0.99        73
#            E       1.00      1.00      1.00        55
#            F       1.00      1.00      1.00       210
#
#     accuracy                           1.00       546
#    macro avg       1.00      1.00      1.00       546
# weighted avg       1.00      1.00      1.00       546

# %%
print_confusion_matrix(y_true, y_pred_my, "Our model predictions for test:", categories)

# %%
y_pred_ultra= get_y_pred(model_my, ultra_test_generator)
y_true_ultra = ultra_test_generator.classes

print_confusion_matrix(y_true_ultra, y_pred_ultra, "Our model predictions for ultra Test:", categories)
# Out:
# C:\Users\arkad\Projekty DataHunters\jdszr9-data_hunters\4 Deep Learning - Types of apples\Utilities\output.py:30: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_generator, steps=len(test_generator), verbose=1)
# 1/1 [==============================] - 1s 795ms/step

# %% [markdown]
# # Błędy:

# %%
PRED= y_pred_my
GENERATOR=test_generator
MODEL=model_my

# %%
PRED= get_y_pred(MODEL, GENERATOR)
y_true = GENERATOR.classes



different_indices = np.where(y_true != PRED)[0]
different_indices


n_batch=0
for batch in GENERATOR:
    X_batch, y_batch = batch
    for i in different_indices:
        if i > n_batch* BATCH_SIZE and i < (n_batch+1) * BATCH_SIZE:
            cat_True=categories[y_true[i]]
            cat_Predict= categories[PRED[i]]
            print(i-n_batch* BATCH_SIZE)
            image = batch[0][i-n_batch* BATCH_SIZE]
            plt.imshow(image)
            plt.title(f'Target = {cat_True} Prediction = {cat_Predict}')
            
            print(y_batch[i-n_batch* BATCH_SIZE])
            
            fig, axes = plt.subplots(1, 2)    
            
            axes[0].imshow(show_random_photo_from_category('data/test',cat_True))
            axes[1].imshow(show_random_photo_from_category('data/test',cat_Predict))
            axes[0].set_title("Target = "+cat_True)
            axes[1].set_title("Prediction= "+cat_Predict)   
            
            #plt.imshow(image)
            #plt.axis('off')
            #plt.title(f'Target = {cat_True} Prediction = {cat_Predict}')
            plt.show()
    
    if different_indices[-1]<n_batch* BATCH_SIZE:
        break
    n_batch+=1
# Out:
# C:\Users\arkad\Projekty DataHunters\jdszr9-data_hunters\4 Deep Learning - Types of apples\Utilities\output.py:30: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_generator, steps=len(test_generator), verbose=1)
# 10/10 [==============================] - 13s 1s/step
# 20
# [0. 1. 0. 0. 0. 0.]
# 46
# [0. 0. 0. 0. 0. 1.]

# %% [markdown]
# # Wyjaśnialność:

# %%
explainer = lime_image.LimeImageExplainer()

# %%
explanation = explainer.explain_instance(image.astype('double'), model_my.predict,  
                                         top_labels=3, hide_color=0, num_samples=50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 231ms/step

# %%
temp_1, mask_1 = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=True)
temp_2, mask_2 = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=10, hide_rest=False)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,15))
ax1.imshow(mark_boundaries(temp_1, mask_1))
ax2.imshow(mark_boundaries(temp_2, mask_2))
ax1.axis('off')
ax2.axis('off')
# Out:
# (-0.5, 321.5, 321.5, -0.5)

# %% [markdown]
# # Aplikacja klasyfikująca jabłka
